# %%
#| hide
from nbdev_hello_world.mymod import *

# %% [markdown]
# # nbdev-hello-world
#
# > Hello world with nbdev

# %% [markdown]
# I want to use `nbdev` for a project but I am not sure what type of project I want to create yet.
#
# This repo was create for the tutorial.
#
# I had a _mostly_ positive experience. There were a few [bumps in the road](https://forums.fast.ai/t/nbdev-tests-fail-on-first-commit/115893/4) but I made it.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbdev_hello_world in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev_hello_world package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev_hello_world
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/eitanlees/nbdev-hello-world.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c eitanlees nbdev_hello_world
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev_hello_world
# ```
#
#
# [repo]: https://github.com/eitanlees/nbdev-hello-world
# [docs]: https://eitanlees.github.io/nbdev-hello-world/
# [pypi]: https://pypi.org/project/nbdev-hello-world/
# [conda]: https://anaconda.org/eitanlees/nbdev-hello-world

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/eitanlees/nbdev-hello-world
# [docs]: https://eitanlees.github.io/nbdev-hello-world/
# [pypi]: https://pypi.org/project/nbdev-hello-world/
# [conda]: https://anaconda.org/eitanlees/nbdev-hello-world

# %% [markdown]
# ## How to use

# %%
say_hello('Eitan')
# Out:
# 'Hello Eitan!'
